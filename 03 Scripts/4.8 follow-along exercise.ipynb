# %% [markdown]
# # 4.8 follow-along exercise

# %% [markdown]
# # 01. Importing Libraries

# %%
# Importlibraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Import data

# %%
# import orders_products_merged_new fro 4.7 for this follow-along
df_ords_prods_merge = pd.read_pickle(r'/Users/bdigregorio/Desktop/CareerFoundry/' \
r'Data Immersion/Data Immersion 4/DI 4.2/Instacart Basket Analysis' \
r'/02 Data/Prepared Data/orders_products_merged_new.pkl')

# %%
path = r'/Users/bdigregorio/Desktop/CareerFoundry/' \
r'Data Immersion/Data Immersion 4/DI 4.2/Instacart Basket Analysis'

# %%
path
# Out:
# '/Users/bdigregorio/Desktop/CareerFoundry/Data Immersion/Data Immersion 4/DI 4.2/Instacart Basket Analysis'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_new.pkl'))

# %%
# Creat a subset or df_ords_prods_merge
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 20)

# %%
df.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_the_week  \
# 0  2539329.0      1.0           1.0                     2.0
# 1  2398795.0      1.0           2.0                     3.0
# 2   473747.0      1.0           3.0                     3.0
# 3  2254736.0      1.0           4.0                     4.0
# 4   431534.0      1.0           5.0                     4.0
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                8.0                     NaN       196.0                1.0
# 1                7.0                    15.0       196.0                1.0
# 2               12.0                    21.0       196.0                1.0
# 3                7.0                    29.0       196.0                1.0
# 4               15.0                    28.0       196.0                1.0
#
#    reordered _merge  Unnamed: 0 product_name  aisle_id  department_id  prices  \
# ...

# %%
df.drop(columns = ["Unnamed: 0"])
# Out:
#          order_id   user_id  order_number  orders_day_of_the_week  \
# 0       2539329.0       1.0           1.0                     2.0
# 1       2398795.0       1.0           2.0                     3.0
# 2        473747.0       1.0           3.0                     3.0
# 3       2254736.0       1.0           4.0                     4.0
# 4        431534.0       1.0           5.0                     4.0
# ...           ...       ...           ...                     ...
# 999995   690549.0  117287.0          14.0                     0.0
# 999996  3327007.0  117287.0          15.0                     5.0
# 999997  1524192.0  117287.0          16.0                     1.0
# 999998  1312255.0  117287.0          17.0                     1.0
# 999999  2704101.0  117287.0          18.0                     1.0
#
#         order_hour_of_day  days_since_prior_order  product_id  \
# 0                     8.0                     NaN       196.0
# ...

# %%
df.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_the_week  \
# 0  2539329.0      1.0           1.0                     2.0
# 1  2398795.0      1.0           2.0                     3.0
# 2   473747.0      1.0           3.0                     3.0
# 3  2254736.0      1.0           4.0                     4.0
# 4   431534.0      1.0           5.0                     4.0
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                8.0                     NaN       196.0                1.0
# 1                7.0                    15.0       196.0                1.0
# 2               12.0                    21.0       196.0                1.0
# 3                7.0                    29.0       196.0                1.0
# 4               15.0                    28.0       196.0                1.0
#
#    reordered _merge  Unnamed: 0 product_name  aisle_id  department_id  prices  \
# ...

# %%
df.groupby('product_name')

# %%
# 3 different ways to aggregate
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4.0              19.315612
# 7.0              17.466053
# 13.0             17.753001
# 14.0             19.246334
# 16.0             19.463012
# 17.0             11.294069
# 19.0             21.234049

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4.0     19.315612
# 7.0     17.466053
# 13.0    17.753001
# 14.0    19.246334
# 16.0    19.463012
# 17.0    11.294069
# 19.0    21.234049
# Name: order_number, dtype: float64

# %%
df.groupby('department_id').order_number.mean()
# Out:
# department_id
# 4.0     19.315612
# 7.0     17.466053
# 13.0    17.753001
# 14.0    19.246334
# 16.0    19.463012
# 17.0    11.294069
# 19.0    21.234049
# Name: order_number, dtype: float64

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean  min   max
# department_id
# 4.0              19.315612  1.0  99.0
# 7.0              17.466053  1.0  99.0
# 13.0             17.753001  1.0  99.0
# 14.0             19.246334  1.0  99.0
# 16.0             19.463012  1.0  99.0
# 17.0             11.294069  1.0  98.0
# 19.0             21.234049  1.0  99.0

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#      order_id  user_id  order_number  orders_day_of_the_week  \
# 0   2539329.0      1.0           1.0                     2.0
# 1   2398795.0      1.0           2.0                     3.0
# 2    473747.0      1.0           3.0                     3.0
# 3   2254736.0      1.0           4.0                     4.0
# 4    431534.0      1.0           5.0                     4.0
# 5   3367565.0      1.0           6.0                     2.0
# 6    550135.0      1.0           7.0                     1.0
# 7   3108588.0      1.0           8.0                     1.0
# 8   2295261.0      1.0           9.0                     1.0
# 9   2550362.0      1.0          10.0                     4.0
# 10  2968173.0     15.0          15.0                     1.0
# 11  1870022.0     15.0          17.0                     2.0
# 12  1911383.0     15.0          18.0                     2.0
# 13  2715276.0     15.0          21.0                     1.0
# ...

# %%
ords_prods_merge[['order_id', 'user_id', 'order_number', 'max_order']].head(25)
# Out:
#      order_id  user_id  order_number  max_order
# 0   2539329.0      1.0           1.0       11.0
# 1   2398795.0      1.0           2.0       11.0
# 2    473747.0      1.0           3.0       11.0
# 3   2254736.0      1.0           4.0       11.0
# 4    431534.0      1.0           5.0       11.0
# 5   3367565.0      1.0           6.0       11.0
# 6    550135.0      1.0           7.0       11.0
# 7   3108588.0      1.0           8.0       11.0
# 8   2295261.0      1.0           9.0       11.0
# 9   2550362.0      1.0          10.0       11.0
# 10  2968173.0     15.0          15.0       23.0
# 11  1870022.0     15.0          17.0       23.0
# 12  1911383.0     15.0          18.0       23.0
# 13  2715276.0     15.0          21.0       23.0
# 14   487368.0     15.0          22.0       23.0
# 15  2293453.0     19.0           2.0       10.0
# 16  1973799.0     19.0           5.0       10.0
# 17   532817.0     19.0           7.0       10.0
# 18  1573906.0     21.0          10.0       34.0
# ...

# %%
ords_prods_merge.head(100)
# Out:
#      order_id  user_id  order_number  orders_day_of_the_week  \
# 0   2539329.0      1.0           1.0                     2.0
# 1   2398795.0      1.0           2.0                     3.0
# 2    473747.0      1.0           3.0                     3.0
# 3   2254736.0      1.0           4.0                     4.0
# 4    431534.0      1.0           5.0                     4.0
# ..        ...      ...           ...                     ...
# 95  3226575.0    360.0           1.0                     5.0
# 96  1469869.0    377.0           3.0                     5.0
# 97  1927023.0    387.0           2.0                     4.0
# 98   858092.0    420.0           4.0                     1.0
# 99   119314.0    420.0           5.0                     3.0
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                 8.0                     NaN       196.0                1.0
# ...

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    16382119
# Loyal customer      10679887
# New customer         5580444
# NaN                       11
# Name: loyalty_flag, dtype: int64

# %%
ords_prods_merge['loyalty_flag']
# Out:
# 0           Regular customer
# 1           Regular customer
# 2           Regular customer
# 3           Regular customer
# 4           Regular customer
#                   ...
# 32642456                 NaN
# 32642457                 NaN
# 32642458                 NaN
# 32642459                 NaN
# 32642460                 NaN
# Name: loyalty_flag, Length: 32642461, dtype: object

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0       1.0  Regular customer           1.0
# 1       1.0  Regular customer           2.0
# 2       1.0  Regular customer           3.0
# 3       1.0  Regular customer           4.0
# 4       1.0  Regular customer           5.0
# 5       1.0  Regular customer           6.0
# 6       1.0  Regular customer           7.0
# 7       1.0  Regular customer           8.0
# 8       1.0  Regular customer           9.0
# 9       1.0  Regular customer          10.0
# 10     15.0  Regular customer          15.0
# 11     15.0  Regular customer          17.0
# 12     15.0  Regular customer          18.0
# 13     15.0  Regular customer          21.0
# 14     15.0  Regular customer          22.0
# 15     19.0      New customer           2.0
# 16     19.0      New customer           5.0
# 17     19.0      New customer           7.0
# 18     21.0  Regular customer          10.0
# 19     31.0  Regular customer          10.0
# ...

# %%
ords_prods_merge['prices'].describe()
# Out:
# count    3.243422e+07
# mean     1.198114e+01
# std      4.954310e+02
# min      1.000000e+00
# 25%      4.200000e+00
# 50%      7.400000e+00
# 75%      1.130000e+01
# max      9.999900e+04
# Name: prices, dtype: float64
