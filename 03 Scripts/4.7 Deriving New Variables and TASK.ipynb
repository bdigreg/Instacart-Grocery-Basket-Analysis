# %% [markdown]
# # Exercise 4.7 - Deriving New Variables

# %% [markdown]
# # 01. Importing Libraries

# %%
# Importlibraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Importing Data

# %%
# import orders_products_prior.csv from Original Data
df_orders_products_merged = pd.read_pickle(r'/Users/bdigregorio/Desktop/CareerFoundry/' \
r'Data Immersion/Data Immersion 4/DI 4.2/Instacart Basket Analysis' \
r'/02 Data/Prepared Data/orders_products_merged.pkl')

# %%
path = r'/Users/bdigregorio/Desktop/CareerFoundry/' \
r'Data Immersion/Data Immersion 4/DI 4.2/Instacart Basket Analysis'

# %%
path
# Out:
# '/Users/bdigregorio/Desktop/CareerFoundry/Data Immersion/Data Immersion 4/DI 4.2/Instacart Basket Analysis'

# %%
df_orders_products_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %% [markdown]
# # 03. Creating user-defined functions with 'if'

# %%
# creating subset for orders_products_merged
df = df_orders_products_merged[:1000000]

# %%
df.shape
# Out:
# (1000000, 17)

# %%
# Define new function

def price_label(row):

  if row['prices'] <= 5:
    return 'Low range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid range product'
  elif row['prices'] > 15:
    return 'High range product'
  else: return 'np.nan'

# %%
# Apply the new function
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/sy/t8rtd3yx6xg83r29mvqjg7cm0000gp/T/ipykernel_1402/1745602380.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# Mid range product    581197
# Low range product    212594
# np.nan               206209
# Name: price_range, dtype: int64

# %% [markdown]
# # 04. Creating user-defined functions with 'if' and 'loc'

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# /var/folders/sy/t8rtd3yx6xg83r29mvqjg7cm0000gp/T/ipykernel_1402/1169838859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product    581197
# Low-range product    212594
# NaN                  206209
# Name: price_range_loc, dtype: int64

# %%
# using loc() on df_orders_products_merged
df_orders_products_merged.loc[df_orders_products_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_orders_products_merged.loc[(df_orders_products_merged['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_orders_products_merged.loc[df_orders_products_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_orders_products_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# NaN                   21516080
# Low-range product     10126324
# Mid-range product       581197
# High-range product      417678
# Name: price_range_loc, dtype: int64

# %% [markdown]
# # 05. If-statements with For-Loops

# %%
df_orders_products_merged['orders_day_of_the_week'].value_counts(dropna = False)
# Out:
# 0.0    6252941
# 1.0    5696724
# 6.0    4530304
# 2.0    4243173
# 5.0    4236989
# 3.0    3868747
# 4.0    3812390
# NaN         11
# Name: orders_day_of_the_week, dtype: int64

# %%
df_orders_products_merged['orders_day_of_the_week'].value_counts(dropna = True)
# Out:
# 0.0    6252941
# 1.0    5696724
# 6.0    4530304
# 2.0    4243173
# 5.0    4236989
# 3.0    3868747
# 4.0    3812390
# Name: orders_day_of_the_week, dtype: int64

# %%
df_orders_products_merged['orders_day_of_the_week'].value_counts()
# Out:
# 0.0    6252941
# 1.0    5696724
# 6.0    4530304
# 2.0    4243173
# 5.0    4236989
# 3.0    3868747
# 4.0    3812390
# Name: orders_day_of_the_week, dtype: int64

# %%
result = []

for value in df_orders_products_merged["orders_day_of_the_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
df_orders_products_merged['busiest_day'] = result

# %%
df_orders_products_merged['busiest_day'].value_counts(dropna =False)
# Out:
# Regularly busy    22575948
# Busiest day        6252941
# Least busy         3812390
# Name: busiest_day, dtype: int64

# %%
print(df_orders_products_merged['busiest_day'])
# Out:
# 0           Regularly busy
# 1           Regularly busy
# 2           Regularly busy
# 3               Least busy
# 4               Least busy
#                  ...
# 32641274    Regularly busy
# 32641275    Regularly busy
# 32641276    Regularly busy
# 32641277    Regularly busy
# 32641278    Regularly busy
# Name: busiest_day, Length: 32641279, dtype: object

# %%
df_orders_products_merged['prices'].describe()
# Out:
# count    3.240487e+07
# mean     1.198022e+01
# std      4.956554e+02
# min      1.000000e+00
# 25%      4.200000e+00
# 50%      7.400000e+00
# 75%      1.130000e+01
# max      9.999900e+04
# Name: prices, dtype: float64

# %% [markdown]
# # 06. 4.7 TASK

# %%
# task step 1 done with reading exercise

# %%
# task step 2 Busiest day and Least busy become busiest days and least busy days

# %%
result = []

for value in df_orders_products_merged['orders_day_of_the_week']:
  if value < 1:
    result.append('Busiest days')
  elif value > 5:
    result.append('Least busy days')
  else:
    result.append('Regularly busy')

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %% [markdown]
# # task step 3. Checks for busiest_days new column

# %%
df_orders_products_merged['busiest_days'] = result

# %%
df_orders_products_merged['busiest_days'].value_counts(dropna =False)
# Out:
# Regularly busy     21858849
# Busiest days        6253163
# Least busy days     4530449
# Name: busiest_days, dtype: int64

# %%
df_orders_products_merged['busiest_days'].shape
# Out:
# (32642461,)

# %%
df_orders_products_merged.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_the_week  \
# 0  2539329.0      1.0           1.0                     2.0
# 1  2398795.0      1.0           2.0                     3.0
# 2   473747.0      1.0           3.0                     3.0
# 3  2254736.0      1.0           4.0                     4.0
# 4   431534.0      1.0           5.0                     4.0
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                8.0                     NaN       196.0                1.0
# 1                7.0                    15.0       196.0                1.0
# 2               12.0                    21.0       196.0                1.0
# 3                7.0                    29.0       196.0                1.0
# 4               15.0                    28.0       196.0                1.0
#
#    reordered _merge  Unnamed: 0 product_name  aisle_id  department_id  prices  \
# ...

# %%
# task step 4 Create a new column containing these labels called “busiest_period_of_day.”

# %%
df_orders_products_merged['order_hour_of_day'].value_counts()
# Out:
# 10.0    2781111
# 11.0    2755471
# 14.0    2709199
# 15.0    2682192
# 13.0    2680274
# 12.0    2637614
# 16.0    2554221
# 9.0     2471137
# 17.0    2104292
# 8.0     1729935
# 18.0    1649934
# 19.0    1268412
# 20.0     983258
# 7.0      897191
# 21.0     801073
# 22.0     638693
# 23.0     405070
# 6.0      292540
# 0.0      220354
# 1.0      116595
# 5.0       88664
# 2.0       69906
# 4.0       53639
# 3.0       51675
# Name: order_hour_of_day, dtype: int64

# %%
result = []

for value in df_orders_products_merged['order_hour_of_day']:
  if value in range (10, 16):
    result.append('Most orders')
  elif value > 6:
    result.append('Fewest orders')
  else:
    result.append('Average orders')

# %%
df_orders_products_merged['Most orders'] = result

# %% [markdown]
# # Checks for Most orders new column

# %%
df_orders_products_merged['Most orders'].value_counts(dropna =False)
# Out:
# Most orders       16245861
# Fewest orders     15503216
# Average orders      893384
# Name: Most orders, dtype: int64

# %%
df_orders_products_merged['Most orders'].shape
# Out:
# (32642461,)

# %%
df_orders_products_merged.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_the_week  \
# 0  2539329.0      1.0           1.0                     2.0
# 1  2398795.0      1.0           2.0                     3.0
# 2   473747.0      1.0           3.0                     3.0
# 3  2254736.0      1.0           4.0                     4.0
# 4   431534.0      1.0           5.0                     4.0
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                8.0                     NaN       196.0                1.0
# 1                7.0                    15.0       196.0                1.0
# 2               12.0                    21.0       196.0                1.0
# 3                7.0                    29.0       196.0                1.0
# 4               15.0                    28.0       196.0                1.0
#
#    reordered _merge  Unnamed: 0 product_name  aisle_id  department_id  prices  \
# ...

# %% [markdown]
# # 07. Exporting orders_products_merged_new as pkl

# %%
df_orders_products_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_new.pkl'))
